# %% [markdown]
# # <H1> Data Science Tools and Ecosystem </H1>

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # <b>Objectives:</b>
# <ul>
# 	<li>Popular languages for Data Science</li>
# 	<li>Common Libraries used by data Scientists</li>
# 	<li>A table of Data Science Tools</li>
# 	<li>Examples of Arithmetic evaluations</li>
# </ul>

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:
# <ol>
# 	<li>Python</li>
# 	<li>R</li>
# 	<li>SQL</li>
# 	<li>JavaScript</li>
# 	<li>Julia</li>
# 	<li>Scalaw</li>
# </ol>

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
# <ol>
# 	<li>Pandas</li>
# 	<li>NumPy</li>
# 	<li>Matplotlib</li>
# 	<li>ggplot2</li>
# 	<li>BigDL</>
# 	<li>Pytorch</>
# 	<li>Keras</>
# 	<li>Apache Spark</>
# </ol>

# %% [markdown]
# # A table of Data Science tools
# <table>
#         <tr >
#             <th colspan="2" style="text-align:center;">Data Science Tools</th>
#         </tr>
#         <tr>
#             <td style="text-align:center;">Jupyter Notebooks (and the JupyterLab)</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;">RStudio</td>
#         </tr>
#         <tr>
#             <td  style="text-align:center;">GitHub</td>
#         </tr>
# </table>

# %% [markdown]
# # <H3>Below are a few examples of evaluating arithmetic expressions in Python</H3>

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
mins = 200
hours = mins/60
print (str(hours) + " hours")
# Out:
# 3.3333333333333335 hours

# %% [markdown]
# # <H2>Aurthor</H2>
# Bunmi Afolabi
